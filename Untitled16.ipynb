# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseParada16/programacion1/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
import statistics
def calcular_promedio(n1, n2, n3):
  return(n1, n2, n3)/3
def mediana (n1, n2, n3):
  return statistics.median([n1, n2, n3])
def moda(n1, n2, n3):
  return statistics.mode([n1, n2, n3])
# Out:
# Writing pedirnotas.py

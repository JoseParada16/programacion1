# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseParada16/programacion1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1

# %%
def suma(z1, z2):
    resultado = z1 + z2
    return resultado

def multiplicacion(z1, z2):
    resultado = z1 * z2
    return resultado

def raiz_n(z, n):
    resultado = z ** (1/n)
    return resultado

def pedir_complejo():
    while True:
        try:
            print("Ingrese la parte real:")
            real = float(input())

            print("Ingrese la parte imaginaria:")
            imag = float(input())

            z = complex(real, imag)
            return z

        except ValueError:
            print("Error: debe ingresar solo números.")


opcion = 0

while opcion != 4:

    print("\nMENU DE OPCIONES")
    print("1. Sumar numeros complejos")
    print("2. Multiplicar numeros complejos")
    print("3. Raiz n-esima de un numero complejo")
    print("4. Salir(si desea terminar)")

    try:
        opcion = int(input("Seleccione una opcion: "))

        if opcion == 1:
            print("Ingrese el primer numero complejo:")
            z1 = pedir_complejo()
            print("Ingrese el segundo numero complejo:")
            z2 = pedir_complejo()
            s = suma(z1, z2)
            print("La suma es:", s)

        elif opcion == 2:
            print("Ingrese el primer numero complejo:")
            z1 = pedir_complejo()
            print("Ingrese el segundo numero complejo:")
            z2 = pedir_complejo()
            s = multiplicacion(z1, z2)
            print("La multiplicacion es:", s)

        elif opcion == 3:
            print("Ingrese el numero complejo:")
            z = pedir_complejo()

            print("Ingrese el valor de n(indice de la raiz):")
            while True:
                try:
                    n = float(input())
                    if n <= 0:
                        print("debe ingresar un numero entero positivo")
                        continue
                    s = raiz_n(z, n)
                    print("La raiz es:", s)
                    break

                except ValueError:
                    print("Error: debe ingresar un numero entero positivo.")

        elif opcion == 4:
            print("Fin del programa")

        else:
            print("Opcion no valida")

    except ValueError:
        print("Error: debe ingresar un numero.")

# %% [markdown]
# MENU DE OPCIONES
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir(si desea terminar)
# Seleccione una opcion: 6
# Opcion no valida
#
# MENU DE OPCIONES
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir(si desea terminar)
# Seleccione una opcion: feer
# Error: debe ingresar un numero.
#
# MENU DE OPCIONES
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir(si desea terminar)
# Seleccione una opcion: 2
# Ingrese el primer numero complejo:
# Ingrese la parte real:
# 2
# Ingrese la parte imaginaria:
# 2
# Ingrese el segundo numero complejo:
# Ingrese la parte real:
# 2
# Ingrese la parte imaginaria:
# 2
# La multiplicacion es: 8j
#
# MENU DE OPCIONES
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir(si desea terminar)
# Seleccione una opcion: 4
# Fin del programa

# %% [markdown]
# Ejercicio 2

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "authorship_tag": "ABX9TyOBbLZMiZN9/5yKJhYDDT0x",
      "include_colab_link": true
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/parxpa1/programacion1/blob/main/trabajo%2C%20semana%20santa\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 23,
      "metadata": {
        "id": "PFvQvyEM16zm"
      },
      "outputs": [],
      "source": [
        "def sumar_vectores(A, B):\n",
        "  filas = len(A)\n",
        "  columnas = len(A[0])\n",
        "  if filas != len(B) or columnas != len(B[0]):\n",
        "    return \"Error: Las matrices deben tener las mismas dimensiones para sumarse.\"\n",
        "  else:\n",
        "    try:\n",
        "      resultado = []\n",
        "      for i in range(filas):\n",
        "        fila = []\n",
        "        for j in range(columnas):\n",
        "          fila.append(float(A[i][j]) + float(B[i][j]))\n",
        "          resultado.append(fila)\n",
        "      return resultado\n",
        "    except ValueError:\n",
        "      return \"Debe ingresar solo números.\""
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "def procudto_punto(A, B):\n",
        "  filas = len(A)\n",
        "  columnas = len(A[0])\n",
        "  if filas != len(B) or columnas != len(B[0]):\n",
        "    return \"Error: Las matrices deben tener las mismas dimensiones para sumarse.\"\n",
        "  else:\n",
        "    try:\n",
        "      resultado = []\n",
        "      for i in range(filas):\n",
        "        fila = []\n",
        "        for j in range(columnas):\n",
        "          fila.append(float(A[i][j]) * float(B[i][j]))\n",
        "          resultado = sum(float(A[i]) * float(B[i]) for i in range(len(A)))\n",
        "      return resultado\n",
        "    except ValueError:\n",
        "      return \"Debe ingresar solo números.\""
      ],
      "metadata": {
        "id": "lGkp5Lkd8X8-"
      },
      "execution_count": 69,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "def producto_cruz(A, B):\n",
        "  filas = len(A)\n",
        "  columnas = len(A[0])\n",
        "  if filas != len(B) or filas !=3:\n",
        "    return \"Error: Las matrices deben tener las mismas dimensiones para sumarse.\"\n",
        "  else:\n",
        "    try:\n",
        "      resultado = []\n",
        "      for i in range(filas):\n",
        "        fila = []\n",
        "        for j in range(columnas):\n",
        "          ai, aj, ak = A[0], A[1], A[2]\n",
        "          bi, bj, bk = B[0], B[1], B[2]\n",
        "          resultado = float(A[1])*float(B[2]) - float(A[2])*float(B[1]), float(A[2])*float(B[0]) - float(A[0])*float(B[2]), float(A[0])*float(B[1]) - float(A[1])*float(B[0])\n",
        "      return resultado\n",
        "    except ValueError:\n",
        "      return \"Debe ingresar solo números.\""
      ],
      "metadata": {
        "id": "KKhVQvDPHPIZ"
      },
      "execution_count": 130,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "def producto_Hadamard(A, B):\n",
        "  filas = len(A)\n",
        "  columnas = len(A[0])\n",
        "  if filas != len(B) or columnas != len(B[0]):\n",
        "    return \"Error: Las matrices deben tener las mismas dimensiones para sumarse.\"\n",
        "  else:\n",
        "    try:\n",
        "      resultado = []\n",
        "      for i in range(filas):\n",
        "        fila = []\n",
        "        for j in range(columnas):\n",
        "          fila.append(float(A[i][j]) * float(B[i][j]))\n",
        "          resultado.append(fila)\n",
        "      return resultado\n",
        "    except ValueError:\n",
        "      return \"Debe ingresar solo números.\""
      ],
      "metadata": {
        "id": "Q2jgg3fncyQB"
      },
      "execution_count": 132,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "v6 = input(\"Ingrese el vector 1 separado por espacios: \").split()\n",
        "v7 = input(\"Ingrese el vector 2 separado por espacios: \").split()\n",
        "operacion = input(\"Ingrese la operación que desea realizar (suma, p.punto, p.cruz, p.Hadamard): \")\n",
        "if operacion == \"suma\":\n",
        "    print (sumar_vectores(v6, v7))\n",
        "elif operacion == \"p.punto\":\n",
        "    print (procudto_punto(v6, v7))\n",
        "elif operacion == \"p.cruz\":\n",
        "    print (producto_cruz(v6, v7))\n",
        "elif operacion == \"p.Hadamard\":\n",
        "    print (producto_Hadamard(v6, v7))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "1IOQUakK6OTe",
        "outputId": "07a3c82b-46c6-479b-d201-e072b9be12ef"
      },
      "execution_count": 134,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Ingrese el vector 1 separado por espacios: 1 2 3 \n",
            "Ingrese el vector 2 separado por espacios: 4 5 6\n",
            "Ingrese la operación que desea realizar (suma, p.punto, p.cruz, p.Hadamard): p.Hadamard\n",
            "[[4.0], [10.0], [18.0]]\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "len(v7)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "DkIdP9o2XEdk",
        "outputId": "032d03e9-2710-40b0-b67e-e840f99e6f05"
      },
      "execution_count": 113,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "2"
            ]
          },
          "metadata": {},
          "execution_count": 113
        }
      ]
    }
  ]
}

# %% [markdown]
# Ejercicio 3

# %%
def ingresar_matriz():
  while True:
    try:
      print("MENU")
      print("1.Sumar matrices")
      print("2.Multiplicar matrices")
      print("3.Producto de Hadamart")
      print("4.Producto de Kronecker")
      print("5.salir")
      opcion=int(input("elija lo que desee hacer: "))

      if opcion == 5:
        print("fin del programa")
        break

      print("PRIMERA MATRIZ")
      filas = int(input("Ingrese el número de filas: "))
      columnas = int(input("Ingrese el número de columnas: "))
      matriz = []

      for i in range(filas):
        while True:
          fila = list(map(float, input(f"Ingrese la fila {i+1} separada por espacios: ").split()))
          if len(fila) != columnas:
            print(f"Error: debe ingresar exactamente {columnas} valores.")
          else:
            matriz.append(fila)
            break

      print("SEGUNDA MATRIZ")
      filas2 = int(input("Ingrese el número de filas: "))
      columnas2 = int(input("Ingrese el número de columnas: "))
      matriz2 = []

      for i in range(filas2):
        while True:
          fila2 = list(map(float, input(f"Ingrese la fila {i+1} separada por espacios: ").split()))
          if len(fila2) != columnas2:
            print(f"Error: debe ingresar exactamente {columnas2} valores.")
          else:
            matriz2.append(fila2)
            break
      print("PRIMERA MATRIZ: ", matriz)
      print("SEGUNDA MATRIZ: ", matriz2)



      if opcion == 1:
        if filas != filas2 or columnas != columnas2:
          print("Error: Las matrices deben tener las mismas dimensiones para sumarse.")
        else:
          resultado = []
          for i in range(filas):
            fila = []
            for j in range(columnas):
              fila.append(matriz[i][j] + matriz2[i][j])
            resultado.append(fila)
          print("la suma es:",resultado)

      elif opcion == 2:
        if columnas != filas2:
           print( "Error: El número de columnas de A debe ser igual al número de filas de B.")
        resultado = []
        for i in range(filas):
          fila = []
          for j in range(columnas2):
            suma = 0
            for k in range(columnas):
              suma += matriz[i][k] * matriz2[k][j]
            fila.append(suma)
          resultado.append(fila)
        print("el producto es: ", resultado)

      elif opcion == 3:
        if filas != filas2 or columnas != columnas2:
          print("Error: Las matrices deben tener las mismas.")
        else:
          resultado = []
          for i in range(filas):
            fila = []
            for j in range(columnas):
              fila.append(matriz[i][j] * matriz2[i][j])
            resultado.append(fila)
          print("el producto de hadamart es:",resultado)

      elif opcion == 4:
        resultado = []
        for i in range(filas):
          for k in range(filas2):
           fila = []
           for j in range(columnas):
              for l in range(columnas2):
                fila.append(matriz[i][j] * matriz2[k][l])
           resultado.append(fila)
        print("el producto de Kronecker es: ", resultado)



    except ValueError:
        print("Error: Ingrese valores válidos.")

# %%
MENU
1.Sumar matrices
2.Multiplicar matrices
3.Producto de Hadamart
4.Producto de Kronecker
5.salir
elija lo que desee hacer: 1
PRIMERA MATRIZ
Ingrese el número de filas: 3
Ingrese el número de columnas: 3
Ingrese la fila 1 separada por espacios: 3 5 3
Ingrese la fila 2 separada por espacios: 5 3 7
Ingrese la fila 3 separada por espacios: 2 6 9
SEGUNDA MATRIZ
Ingrese el número de filas: 3
Ingrese el número de columnas: 3
Ingrese la fila 1 separada por espacios: 3 5 8
Ingrese la fila 2 separada por espacios: 1 8 2
Ingrese la fila 3 separada por espacios: 6 9 2
PRIMERA MATRIZ:  [[3.0, 5.0, 3.0], [5.0, 3.0, 7.0], [2.0, 6.0, 9.0]]
SEGUNDA MATRIZ:  [[3.0, 5.0, 8.0], [1.0, 8.0, 2.0], [6.0, 9.0, 2.0]]
la suma es: [[6.0, 10.0, 11.0], [6.0, 11.0, 9.0], [8.0, 15.0, 11.0]]
MENU
1.Sumar matrices
2.Multiplicar matrices
3.Producto de Hadamart
4.Producto de Kronecker
5.salir
elija lo que desee hacer: 5
fin del programa

# %% [markdown]
# Ejercicio 4

# %%
def ingresar_matriz():
    filas = int(input("Ingrese el número de filas: "))
    columnas = int(input("Ingrese el número de columnas: "))

    matriz = []
    for i in range(filas):
        while True:
            fila = list(map(float, input(f"Ingrese la fila {i+1} separada por espacios: ").split()))
            if len(fila) != columnas:
                print(f"Error: para las filas debe ingresar {columnas} valores.")
            else:
                matriz.append(fila)
                break
    return matriz

# %%
def transponer(matriz):
    return [list(fila) for fila in zip(*matriz)]

# %%
def menor(matriz, i, j):
    return [fila[:j] + fila[j+1:] for fila in (matriz[:i] + matriz[i+1:])]

# %%
def determinante(matriz):
    if len(matriz) == 2:
        return matriz[0][0]*matriz[1][1] - matriz[0][1]*matriz[1][0]

    determinante = 0
    for c in range(len(matriz)):
        det += ((-1)**c) * matriz[0][c] * determinante(menor(matriz, 0, c))
    return determinante

# %%
def cofactores(matriz):
    n = len(matriz)
    cofactores = []

    for i in range(n):
        fila = []
        for j in range(n):
            m = menor(matriz, i, j)
            valor = ((-1)**(i+j)) * determinante(m)
            fila.append(valor)
        cof.append(fila)

    return cofactores

# %%
def vectorizar(matriz):
    vector = []
    for fila in matriz:
        for elemento in fila:
            vector.append(elemento)
    return vector

# %%
def mostrar_matriz(m):
    for fila in m:
        print(fila)

# %%
while True:
    print("1. Transponer matriz")
    print("2. Matriz de cofactores")
    print("3. Vectorizar por filas")
    print("4. Salir")

    opcion = input("Elija una opción: ")

    if opcion == "1":
        A = ingresar_matriz()
        print("Transpuesta:")
        mostrar_matriz(transponer(A))

    elif opcion == "2":
        A = ingresar_matriz()
        print("Matriz de cofactores:")
        mostrar_matriz(cofactores(A))

    elif opcion == "3":
        A = ingresar_matriz()
        print("Vectorización:")
        print(vectorizar(A))

    elif opcion == "4":
        print("Fin del programa")
        break

    else:
        print("Opción inválida")

# %% [markdown]
# Nombre integrantes:

# %% [markdown]
# Jose Daniel Parada Ropero

# %% [markdown]
# Kevin Jhovany Cruz Ortiz

# %% [markdown]
# Juan Diego Prada Gonzales

# %% [markdown]
# Sergio Andrés Caballero Hernández
